# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/My Drive/war.txt'
text = open(path, 'r' , errors='ignore').read()
text = text.lower()

# %%
# Length of extracted character sequences
maxlen = 150

# We sample a new sequence every `step` characters
step = 2

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Out:
# Number of sequences: 162068
# Unique characters: 46

# %%
len(text)
# Out:
# 324286

# %%
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# %%
# Next, one-hot encode the characters into binary arrays.
X = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1

# %%
from keras.layers import Dense , LSTM ,Dropout
from keras.models import Sequential
import keras

# %%
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars)) , return_sequences = True))
model.add(Dropout (0.1))
model.add(LSTM(128))
model.add(Dense(len(chars), activation='softmax'))

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
# For randomly selecting unique characters
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

for epoch in range(1, 20):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(X, y,
              batch_size=128,
              epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    actual_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + actual_text + '"')
    print('--------------\n')

    for temperature in [0.2,0.5,1]:
        generated_text = actual_text 
        # We generate 100 characters
        for i in range(100):
            sampled = np.zeros((1, maxlen, len(chars)))
            
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            #sys.stdout.write(next_char)
            sys.stdout.flush()
        print('------ temperature:' + str(temperature) + ' -> ' )
        sys.stdout.write(actual_text)
        sys.stdout.write(generated_text)
        print()
        print('\n')
# Out:
# epoch 1
# 1267/1267 [==============================] - 28s 22ms/step - loss: 2.1477
# --- Generating with seed: "rough the clearness of the planets atmosphere and obscured
# its more familiar features.
#
# even the daily papers woke up to the disturbances at last, and"
# --------------
#
# ------ temperature:0.2 ->
# rough the clearness of the planets atmosphere and obscured
# its more familiar features.
#
# even the daily papers woke up to the disturbances at last, andly papers woke up to the disturbances at last, and the stepled of the steple the saided and the steple of the steped and the stater and the stepped an
#
#
# ------ temperature:0.5 ->
# rough the clearness of the planets atmosphere and obscured
# its more familiar features.
#
# even the daily papers woke up to the disturbances at last, andly papers woke up to the disturbances at last, and the road as martian. i shoped me pane the seen a his have have stod of the pily the black of the sa
#
#
# ------ temperature:1 ->
# rough the clearness of the planets atmosphere and obscured
# its more familiar features.
#
# even the daily papers woke up to the disturbances at last, andly papers woke up to the disturbances at last, and the firs.
#
# as our the ameason of the spuch mist, and
# i far our reen, skided i reps-aindoban was the
#
#
# epoch 2
# 1267/1267 [==============================] - 28s 22ms/step - loss: 1.6850
# --- Generating with seed: "ead, screaming.
#
# theyre coming! a woman shrieked, and incontinently everyone was
# turning and pushing at those behind, in order to clear their way to
# w"
# --------------
#
# ------ temperature:0.2 ->
# ead, screaming.
#
# theyre coming! a woman shrieked, and incontinently everyone was
# turning and pushing at those behind, in order to clear their way to
# w at those behind, in order to clear their way to
# wend and streets of the couple of the rease of the couple of the streets of the streets and the concu
#
#
# ------ temperature:0.5 ->
# ead, screaming.
#
# theyre coming! a woman shrieked, and incontinently everyone was
# turning and pushing at those behind, in order to clear their way to
# w at those behind, in order to clear their way to
# we could ceamed the contrayed and from the road, the way contingly and common, and darked the conneck
#
#
# ------ temperature:1 ->
# ead, screaming.
#
# theyre coming! a woman shrieked, and incontinently everyone was
# turning and pushing at those behind, in order to clear their way to
# w at those behind, in order to clear their way to
# weams of
#
# the movestible stoning the srekmed and perwy hamppling, but shils being of the house, the p
#
#
# epoch 3
# 1267/1267 [==============================] - 29s 23ms/step - loss: 1.5811
# --- Generating with seed: "stream. i saw people
# struggling shorewards, and heard their screaming and shouting faintly
# above the seething and roar of the martians collapse.
#
# for "
# --------------
#
# ------ temperature:0.2 ->
# stream. i saw people
# struggling shorewards, and heard their screaming and shouting faintly
# above the seething and roar of the martians collapse.
#
# for  seething and roar of the martians collapse.
#
# for the road the streets and still of the remoine the martians and the road the martians was a street th
#
#
# ------ temperature:0.5 ->
# stream. i saw people
# struggling shorewards, and heard their screaming and shouting faintly
# above the seething and roar of the martians collapse.
#
# for  seething and roar of the martians collapse.
#
# for the pro.sing of the passed the patter in a companicw the fut furning so form the sens the martians o
#
#
# ------ temperature:1 ->
# stream. i saw people
# struggling shorewards, and heard their screaming and shouting faintly
# above the seething and roar of the martians collapse.
#
# for  seething and roar of the martians collapse.
#
# for a reed, his cool the number spials stanew of gew was anour they weemen of them drose another, was to
#
#
# epoch 4
# 1267/1267 [==============================] - 29s 23ms/step - loss: 1.5259
# --- Generating with seed: "from a dangerous
# case at pinner, and heard at some railway station on his way of the
# martian advance. he had hurried home, roused the womentheir serva"
# --------------
#
# ------ temperature:0.2 ->
# from a dangerous
# case at pinner, and heard at some railway station on his way of the
# martian advance. he had hurried home, roused the womentheir serva. he had hurried home, roused the womentheir servation of the street and the street the street and the street to the street the street and the street
#
#
# ------ temperature:0.5 ->
# from a dangerous
# case at pinner, and heard at some railway station on his way of the
# martian advance. he had hurried home, roused the womentheir serva. he had hurried home, roused the womentheir servation of see the third the martian had northwards my wife the fight the seen might from the veople to
#
#
# ------ temperature:1 ->
# from a dangerous
# case at pinner, and heard at some railway station on his way of the
# martian advance. he had hurried home, roused the womentheir serva. he had hurried home, roused the womentheir servance to the bouting of called and to london, and swill, and the vease high rink round falleg, lurbing
#
#
# epoch 5
# 1267/1267 [==============================] - 29s 23ms/step - loss: 1.4918
# --- Generating with seed: "three of them contrived to eat a meal on one of the seats forward.
#
# there were already a couple of score of passengers aboard, some of whom
# had expend"
# --------------
#
# ------ temperature:0.2 ->
# three of them contrived to eat a meal on one of the seats forward.
#
# there were already a couple of score of passengers aboard, some of whom
# had expendcore of passengers aboard, some of whom
# had expended the streamed the streamed the street of the seen the streamed the troubt the streamed and the str
#
#
# ------ temperature:0.5 ->
# three of them contrived to eat a meal on one of the seats forward.
#
# there were already a couple of score of passengers aboard, some of whom
# had expendcore of passengers aboard, some of whom
# had expended to move and faroes and gunned the fived to the days of the more and to the fared a days, and stoo
#
#
# ------ temperature:1 ->
# three of them contrived to eat a meal on one of the seats forward.
#
# there were already a couple of score of passengers aboard, some of whom
# had expendcore of passengers aboard, some of whom
# had expended
# touch, and were breabed orthey amoury was to the lotted, difh. then it was realis appazed sicslin
#
#
# epoch 6
# 1267/1267 [==============================] - 29s 23ms/step - loss: 1.4683
# --- Generating with seed: "hundred miles east of him.
#
# i was at home at that hour and writing in my study; and although my
# french windows face towards ottershaw and the blind wa"
# --------------
#
# ------ temperature:0.2 ->
# hundred miles east of him.
#
# i was at home at that hour and writing in my study; and although my
# french windows face towards ottershaw and the blind wach windows face towards ottershaw and the blind was a street of the streets of the red with a street of the streets of the streets and the martians an
#
#
# ------ temperature:0.5 ->
# hundred miles east of him.
#
# i was at home at that hour and writing in my study; and although my
# french windows face towards ottershaw and the blind wach windows face towards ottershaw and the blind was of the said the streets of the highed and then the seled on the pushed in the streets of the light
#
#
# ------ temperature:1 ->
# hundred miles east of him.
#
# i was at home at that hour and writing in my study; and although my
# french windows face towards ottershaw and the blind wach windows face towards ottershaw and the blind was cace beer edge such far the wrading of the gods.
#
# go on-thinksson.
#
# my brother
# have gounging this
#
#
# epoch 7
# 1267/1267 [==============================] - 29s 23ms/step - loss: 1.4490
# --- Generating with seed: ", and bolted into the scullery. the curate, who had been crouching
# silently with his arms over his head, looked up as i passed, cried out
# quite loudly"
# --------------
#
# ------ temperature:0.2 ->
# , and bolted into the scullery. the curate, who had been crouching
# silently with his arms over his head, looked up as i passed, cried out
# quite loudlyead, looked up as i passed, cried out
# quite loudly a man of the martians and direction of the houses and the road a back of the streets of the distant
#
#
# ------ temperature:0.5 ->
# , and bolted into the scullery. the curate, who had been crouching
# silently with his arms over his head, looked up as i passed, cried out
# quite loudlyead, looked up as i passed, cried out
# quite loudly on the trees a thing was i saw the little great out of the house and down the houses at the part of
#
#
# ------ temperature:1 ->
# , and bolted into the scullery. the curate, who had been crouching
# silently with his arms over his head, looked up as i passed, cried out
# quite loudlyead, looked up as i passed, cried out
# quite loudly the paptiant of a machine road, little al basmen effor-round out of the shodical fountile. he was t
#
#
# epoch 8
# 1267/1267 [==============================] - 29s 23ms/step - loss: 1.4348
# --- Generating with seed: "ps a vague idea of making his way to chelmsford, where some
# friends of his lived, that at last induced my brother to strike into a
# quiet lane running "
# --------------
#
# ------ temperature:0.2 ->
# ps a vague idea of making his way to chelmsford, where some
# friends of his lived, that at last induced my brother to strike into a
# quiet lane running ed my brother to strike into a
# quiet lane running of the streamed to the red was a hundred standing out of the street and street the streets of the st
#
#
# ------ temperature:0.5 ->
# ps a vague idea of making his way to chelmsford, where some
# friends of his lived, that at last induced my brother to strike into a
# quiet lane running ed my brother to strike into a
# quiet lane running of the streamed at the bridge but became streets and thing of the distumbled out of the street. i ha
#
#
# ------ temperature:1 ->
# ps a vague idea of making his way to chelmsford, where some
# friends of his lived, that at last induced my brother to strike into a
# quiet lane running ed my brother to strike into a
# quiet lane running now were strange. i was from almost when was i had the number of rives the artilleryman away
# upon me
#
#
# epoch 9
# 1267/1267 [==============================] - 29s 23ms/step - loss: 1.4212
# --- Generating with seed: "ridge about half past eight. we hurried across the exposed bridge, of
# course, but i noticed floating down the stream a number of red masses,
# some many"
# --------------
#
# ------ temperature:0.2 ->
# ridge about half past eight. we hurried across the exposed bridge, of
# course, but i noticed floating down the stream a number of red masses,
# some many down the stream a number of red masses,
# some many station of the strange and the sound of the strange the strange and strange of the strange of the s
#
#
# ------ temperature:0.5 ->
# ridge about half past eight. we hurried across the exposed bridge, of
# course, but i noticed floating down the stream a number of red masses,
# some many down the stream a number of red masses,
# some many was a secure and so road of the martians gave a man shop. i saw a come in the same in the road of a
#
#
# ------ temperature:1 ->
# ridge about half past eight. we hurried across the exposed bridge, of
# course, but i noticed floating down the stream a number of red masses,
# some many down the stream a number of red masses,
# some many incridreubt into otter hundred a
# panissely with came the thing of for the wass. they seemed to
# rema
#
#
# epoch 10
# 1267/1267 [==============================] - 29s 23ms/step - loss: 1.4139
# --- Generating with seed: "ab struck his
# shoulder and sent him reeling. he gave a shriek and dodged back, and a
# cartwheel shaved him narrowly.
#
# way! cried the men all about him."
# --------------
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.
# ------ temperature:0.2 ->
# ab struck his
# shoulder and sent him reeling. he gave a shriek and dodged back, and a
# cartwheel shaved him narrowly.
#
# way! cried the men all about him.d him narrowly.
#
# way! cried the men all about him. i had been the heat-ray were began the scarcely a man were heaving of the strange had been had been
#
#
# ------ temperature:0.5 ->
# ab struck his
# shoulder and sent him reeling. he gave a shriek and dodged back, and a
# cartwheel shaved him narrowly.
#
# way! cried the men all about him.d him narrowly.
#
# way! cried the men all about him. and the
# whispered and spiced by the face of the strange busin of
# horses what was he saw a soon had
#
#
# ------ temperature:1 ->
# ab struck his
# shoulder and sent him reeling. he gave a shriek and dodged back, and a
# cartwheel shaved him narrowly.
#
# way! cried the men all about him.d him narrowly.
#
# way! cried the men all about him. was
# i two barning of human what we must for the grouss hand, movement from
# oursterrdies horrable as
#
#
# epoch 11
# 1267/1267 [==============================] - 29s 23ms/step - loss: 1.4065
# --- Generating with seed: "storm just at this place that i had the hardest task to win my way
# up the hill. i went close up to the fence on the left and worked my way
# along its p"
# --------------
#
# ------ temperature:0.2 ->
# storm just at this place that i had the hardest task to win my way
# up the hill. i went close up to the fence on the left and worked my way
# along its phe fence on the left and worked my way
# along its paind the fire in the staring the pit the thing was a sound the martians and the thing of the streets
#
#
# ------ temperature:0.5 ->
# storm just at this place that i had the hardest task to win my way
# up the hill. i went close up to the fence on the left and worked my way
# along its phe fence on the left and worked my way
# along its paind the paindly again and was a sound and stood about the forecond the people were got of the paind
#
#
# ------ temperature:1 ->
# storm just at this place that i had the hardest task to win my way
# up the hill. i went close up to the fence on the left and worked my way
# along its phe fence on the left and worked my way
# along its pame with like
# an
# give like problieuth of water right
# i was
# to be fance uhe looking possibly pifons o
#
#
# epoch 12
# 1267/1267 [==============================] - 29s 23ms/step - loss: 1.4005
# --- Generating with seed: "nment that i peeped for the last
# time, and presently found myself alone. instead of keeping close to me
# and trying to oust me from the slit, the curat"
# --------------
#
# ------ temperature:0.2 ->
# nment that i peeped for the last
# time, and presently found myself alone. instead of keeping close to me
# and trying to oust me from the slit, the curat me
# and trying to oust me from the slit, the curate, and the
# streets and seemed a man when i was seemed a broad and streets of the waters and a man wa
#
#
# ------ temperature:0.5 ->
# nment that i peeped for the last
# time, and presently found myself alone. instead of keeping close to me
# and trying to oust me from the slit, the curat me
# and trying to oust me from the slit, the curate odner
# relling the thunderstorms, and as the
# seculate far add were even these trees came the river
#
#
# ------ temperature:1 ->
# nment that i peeped for the last
# time, and presently found myself alone. instead of keeping close to me
# and trying to oust me from the slit, the curat me
# and trying to oust me from the slit, the curate.
#
# and very dared.
#
# i
# trough lrees loasmon whirstle, and of the human common with theirs was eatter
#
#
# epoch 13
# 1267/1267 [==============================] - 29s 23ms/step - loss: 1.3936
# --- Generating with seed: "; he looked, indeed, as though he had been dragged
# through a culvert. nearer, i distinguished the green slime of ditches
# mixing with the pale drab of "
# --------------
#
# ------ temperature:0.2 ->
# ; he looked, indeed, as though he had been dragged
# through a culvert. nearer, i distinguished the green slime of ditches
# mixing with the pale drab of een slime of ditches
# mixing with the pale drab of the streets of the streets of the common. i said, and the still streets of the streets of the street
#
#
# ------ temperature:0.5 ->
# ; he looked, indeed, as though he had been dragged
# through a culvert. nearer, i distinguished the green slime of ditches
# mixing with the pale drab of een slime of ditches
# mixing with the pale drab of the strange of the things to the scullery and blackness, seem to spring of the rained about the hors
#
#
# ------ temperature:1 ->
# ; he looked, indeed, as though he had been dragged
# through a culvert. nearer, i distinguished the green slime of ditches
# mixing with the pale drab of een slime of ditches
# mixing with the pale drab of the famity that the shopped
# my come the lightwhone air. experal bout, had have had i poured, diging
#
#
# epoch 14
# 1267/1267 [==============================] - 29s 23ms/step - loss: 1.3868
# --- Generating with seed: "of dawn.
# yet here and there some object had had the luck to escapea white
# railway signal here, the end of a greenhouse there, white and fresh
# amid the"
# --------------
#
# ------ temperature:0.2 ->
# of dawn.
# yet here and there some object had had the luck to escapea white
# railway signal here, the end of a greenhouse there, white and fresh
# amid thend of a greenhouse there, white and fresh
# amid the martians and the streets of the streets of the streamer of the martians and the sudden in the strea
#
#
# ------ temperature:0.5 ->
# of dawn.
# yet here and there some object had had the luck to escapea white
# railway signal here, the end of a greenhouse there, white and fresh
# amid thend of a greenhouse there, white and fresh
# amid the streets and the streets and of the planet greatly as the places and of the other busy brown bridge.
#
#
# ------ temperature:1 ->
# of dawn.
# yet here and there some object had had the luck to escapea white
# railway signal here, the end of a greenhouse there, white and fresh
# amid thend of a greenhouse there, white and fresh
# amid the light.
#
# it was the curates was ais
# excreasly abone possiblent and dopth martians mole in brathey we
#
#
# epoch 15
# 1267/1267 [==============================] - 29s 23ms/step - loss: 1.3826
# --- Generating with seed: "er, and i
# verily believe that to the very end this spoiled child of life thought
# his weak tears in some way efficacious. and i would sit in the darkne"
# --------------
#
# ------ temperature:0.2 ->
# er, and i
# verily believe that to the very end this spoiled child of life thought
# his weak tears in some way efficacious. and i would sit in the darkneome way efficacious. and i would sit in the darkness of the streets of the first the started and the water of the black smoke had a common and the com
#
#
# ------ temperature:0.5 ->
# er, and i
# verily believe that to the very end this spoiled child of life thought
# his weak tears in some way efficacious. and i would sit in the darkneome way efficacious. and i would sit in the darkness, in the water streets the thing of the water. i was streets shop of the houses and the carriage s
#
#
# ------ temperature:1 ->
# er, and i
# verily believe that to the very end this spoiled child of life thought
# his weak tears in some way efficacious. and i would sit in the darkneome way efficacious. and i would sit in the darkness the enicured. it was such slept in the pine bulway nog, clampingotsbegetical and dongic the secon
#
#
# epoch 16
# 1267/1267 [==============================] - 29s 23ms/step - loss: 1.3787
# --- Generating with seed: ", and pointed out mars, a
# bright dot of light creeping zenithward, towards which so many
# telescopes were pointed. it was a warm night. coming home, a "
# --------------
#
# ------ temperature:0.2 ->
# , and pointed out mars, a
# bright dot of light creeping zenithward, towards which so many
# telescopes were pointed. it was a warm night. coming home, a were pointed. it was a warm night. coming home, a bridge of the stilled and station of the common station of the common had been the station of the ma
#
#
# ------ temperature:0.5 ->
# , and pointed out mars, a
# bright dot of light creeping zenithward, towards which so many
# telescopes were pointed. it was a warm night. coming home, a were pointed. it was a warm night. coming home, a found the sculle of the stilled and worked for the destroyed to the hatkers. i was began and then as
#
#
# ------ temperature:1 ->
# , and pointed out mars, a
# bright dot of light creeping zenithward, towards which so many
# telescopes were pointed. it was a warm night. coming home, a were pointed. it was a warm night. coming home, a subling, ringing a droidible red-seakny, ostiply.
# deeply. there had see, on at the
# chaverious and si
#
#
# epoch 17
# 1267/1267 [==============================] - 29s 23ms/step - loss: 1.3763
# --- Generating with seed: ", one heard the whirr of a machine-gun that
# was presently stilled, and an intermittent cracking of rifles.
# apparently the martians were setting fire t"
# --------------
#
# ------ temperature:0.2 ->
# , one heard the whirr of a machine-gun that
# was presently stilled, and an intermittent cracking of rifles.
# apparently the martians were setting fire tifles.
# apparently the martians were setting fire that the streets of the description of the first in the black and standing the common. the steambury
#
#
# ------ temperature:0.5 ->
# , one heard the whirr of a machine-gun that
# was presently stilled, and an intermittent cracking of rifles.
# apparently the martians were setting fire tifles.
# apparently the martians were setting fire the pit in the houses, the little circumour of the first heave and then i had do the common. it was s
#
#
# ------ temperature:1 ->
# , one heard the whirr of a machine-gun that
# was presently stilled, and an intermittent cracking of rifles.
# apparently the martians were setting fire tifles.
# apparently the martians were setting fire that had way tasfhey passed, a and their
# spubme of anrungary.
#
# his treed of the
# off smoke of glowel,
#
#
# epoch 18
# 1267/1267 [==============================] - 29s 23ms/step - loss: 1.3717
# --- Generating with seed: "e things, he
# turned hastily to his own room, put all his available moneysome ten
# pounds altogetherinto his pockets, and went out again into the
# street"
# --------------
#
# ------ temperature:0.2 ->
# e things, he
# turned hastily to his own room, put all his available moneysome ten
# pounds altogetherinto his pockets, and went out again into the
# streetto his pockets, and went out again into the
# streets of the steamer was the sunday was a thing was the streets were courage the streets were be and the
#
#
# ------ temperature:0.5 ->
# e things, he
# turned hastily to his own room, put all his available moneysome ten
# pounds altogetherinto his pockets, and went out again into the
# streetto his pockets, and went out again into the
# streets were companion of the common, beyond the sunsterness that a miles of the forming the road, and lig
#
#
# ------ temperature:1 ->
# e things, he
# turned hastily to his own room, put all his available moneysome ten
# pounds altogetherinto his pockets, and went out again into the
# streetto his pockets, and went out again into the
# streets, fet up a smoke, i said, swiped for leather. in his clumbers of
# rustless relooses hill invisible
# m
#
#
# epoch 19
# 1267/1267 [==============================] - 29s 23ms/step - loss: 1.3722
# --- Generating with seed: "f these appearances in order to appreciate fully their
# remarkable resemblance in character.
#
# at any rate, whether we expect another invasion or not, o"
# --------------
#
# ------ temperature:0.2 ->
# f these appearances in order to appreciate fully their
# remarkable resemblance in character.
#
# at any rate, whether we expect another invasion or not, orate, whether we expect another invasion or not, out of the streets of the part, and the way of the common to see the streets of the confusion watch o
#
#
# ------ temperature:0.5 ->
# f these appearances in order to appreciate fully their
# remarkable resemblance in character.
#
# at any rate, whether we expect another invasion or not, orate, whether we expect another invasion or not, one of the streets, and and so in the reveloor, and the some withmuch something seen heeded to see it
#
#
# ------ temperature:1 ->
# f these appearances in order to appreciate fully their
# remarkable resemblance in character.
#
# at any rate, whether we expect another invasion or not, orate, whether we expect another invasion or not, on the wheel came papious, and for fer deep fluck about the starustity from a man being came. we saw

# %% [markdown]
# ## Take aways
#
# * You can see that generated text is not good but the model has learned something new !
# * You can improve by training a bigger model, longer, on more data, you can achieve generated samples that will look much more coherent and realistic than ours.
# *  But of course, don't expect to ever generate any meaningful text, other than by random chance: all we are doing is sampling data from a statistical model of which characters come after which characters.
# * We can  also try to build a model to perdict next token ,given previous tokens. This is called as "language model".
